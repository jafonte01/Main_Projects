# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import chardet

# %% [markdown]
# Below is my solution to a UnicodeDecodeError problem I was having. I could have done the following other things, which I will keep here as personal notes:
#
# 1.
# with open('filename.csv', 'rb') as f: result = chardet.detect(f.read()) # or readline if the file is large such as f.read(10242) for the first megabyte.
# pd.read_csv('filename.csv', encoding=result['encoding'])
#
# 2.
# df = pd.read_csv(r"filename.csv", encoding="cp1252") # r is for "raw string" to further avoid complications
#
# 3.
# Opening the csv in notepad++, going to encoding menu, choose utf-8, and save over file OR go to sublimetext and save with utf-8 encoding THEN load the overwritten csv (will have to download either of these to do this option).
#
# 4.
# Another option is to cover up the errors by passing an error handler:
#
# ifd = open("infile.csv", 'r', errors='replace')
#
# 5.
# My Mentor's Method (didn't work for me)
# import csv
#
# with open('../Data/Welcome_Trust_Prices_2012_to_2013/WELLCOME_APCspend2013_forThinkful.csv',
#           newline='', encoding='utf-8') as file:
#     for row in csv.reader(file):
#         print(row)
#
# __NOTE:__ I did not test to see if any of these options actually work (although the third option seems that it would work intuitively). Again, just noting for posterity.

# %%
df = pd.read_csv('../Data/Welcome_Trust_Prices_2012_to_2013/WELLCOME_APCspend2013_forThinkful.csv', encoding='latin-1')
### setting the encoding to utf-8 still pushed a decode error. I can play around with the original file to find the fault
# but using latin 1 is a quick workaround, and I haven't seen any resulting mojibake.

df.tail()
# Out:
#                             PMID/PMCID                      Publisher  \
# 2122                           2901593          Wolters Kluwer Health
# 2123                           3748854         Wolters Kluwer Health
# 2124                           3785148         Wolters Kluwer Health
# 2125          PMCID:\n    PMC3647051\n  Wolters Kluwer N.V./Lippinott
# 2126  PMID: 23846567  (Epub July 2013)                Wolters Kluwers
#
#                                         Journal title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                             Pediatr Infect Dis J
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title  \
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75

# %% [markdown]
# ## Assignment Goals
#
# 1. Determine the five most common journals and the total articles for each.
#
# 2. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal. You will need to do considerable data cleaning in order to extract accurate estimates, and may want to look into data encoding methods if you get stuck.
#
# 3. For a real bonus round, identify the open access prices paid by subject area.

# %%
# for the first goal
df['Journal title'].value_counts() # I see the Plos One problem...
# Out:
# PLoS One                                                              92
# PLoS ONE                                                              62
# Journal of Biological Chemistry                                       48
# Nucleic Acids Research                                                21
# Proceedings of the National Academy of Sciences                       19
# PLoS Neglected Tropical Diseases                                      18
# Human Molecular Genetics                                              18
# Nature Communications                                                 17
# PLoS Genetics                                                         15
# PLoS Pathogens                                                        15
# Neuroimage                                                            15
# BMC Public Health                                                     14
# Brain                                                                 14
# NeuroImage                                                            14
# PLOS ONE                                                              14
# Movement Disorders                                                    13
# Developmental Cell                                                    12
# Journal of Neuroscience                                               12
# Biochemical Journal                                                   12
# Journal of General Virology                                           11
# Current Biology                                                       10
# BMJ                                                                   10
# PLOS One                                                              10
# Neuron                                                                 9
# Cell Reports                                                           9
# Malaria Journal                                                        8
# Development                                                            8
# Proceedings of the Royal Society B: Biological Sciences                8
# Hepatology                                                             8
# Journal of Physiology                                                  8
#                                                                       ..
# BMC Medical Ethics                                                     1
# Febs Letters                                                           1
# BMC  Public Health                                                     1
# BMC Veterinary Research                                                1
# International Journal of Parasitology                                  1
# Haematologica                                                          1
# Physics in Biology and Medicine\n                                      1
# Chemical Communication                                                 1
# International Reviews of Immunology                                    1
# British Journal of Clinical Pharmacology                               1
# Infection Genetics and Evolution                                       1
# Nitric Oxide                                                           1
# Experimental Cell Research                                             1
# Pflugers Archiv                                                        1
# Neurobiology of Disease                                                1
# Journal of Clinical Endocrinology                                      1
# Applied Energy                                                         1
# Acta Dermato Venereologica                                             1
# Protein Expr Purif.                                                    1
# HPB                                                                    1
# Journal of Biological Physics                                          1
# Transactions of the Royal Society of Tropical Medicine and Hygiene     1
# Age                                                                    1
# Nucleic Acids Research\n                                               1
# Frontiers in Neural Circuits                                           1
# Hum Resour Health                                                      1
# Philos Trans R Soc London B Biol Sci                                   1
# Expert Reviews in Molecular Medicine                                   1
# Development Genes and Evolution                                        1
# Neuroimage: clinical                                                   1
# Name: Journal title, Length: 984, dtype: int64

# %%
# making various replacements

df['Journal title'] = df['Journal title'].str.replace('J ', 'Journal ')
df['Journal title'] = df['Journal title'].str.replace('fro ', 'for ')
df['Journal title'] = df['Journal title'].str.replace('The ', '')
df['Journal title'] = df['Journal title'].str.replace('the ', '')

df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS        Journal Med Chem
# 3    23438330 PMC3646402       ACS        Journal Med Chem
# 4   23438216 PMC3601604        ACS        Journal Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# doing it piecemeal just in case something breaks 

df['Journal title'] = df['Journal title'].str.replace('Biol ', 'Biological ')
df['Journal title'] = df['Journal title'].str.replace('Med ', 'Medical ')
df['Journal title'] = df['Journal title'].str.replace('Chem ', ' Chemistry ')
df['Journal title'] = df['Journal title'].str.replace('BioMed Central', 'BMC')

# %%
df['Journal title'].replace('Pediatr Infect Dis J', 'Pediatric Infection Dis Journal', inplace=True)
df.tail()

# realized I had to do "inplace" for correct replacement.
# why else would I do a replacement if not for inplace?!?!?!
# Out:
#                             PMID/PMCID                      Publisher  \
# 2122                           2901593          Wolters Kluwer Health
# 2123                           3748854         Wolters Kluwer Health
# 2124                           3785148         Wolters Kluwer Health
# 2125          PMCID:\n    PMC3647051\n  Wolters Kluwer N.V./Lippinott
# 2126  PMID: 23846567  (Epub July 2013)                Wolters Kluwers
#
#                                         Journal title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                  Pediatric Infection Dis Journal
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title  \
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75

# %%
df['Journal title'] = df['Journal title'].str.replace('Jnl ', 'Journal ')
df['Journal title'] = df['Journal title'].str.replace('British Medical Journal', 'BMJ')
df['Journal title'] = df['Journal title'].str.replace('&', 'and')
df['Journal title'] = df['Journal title'].str.replace('Virol ', 'Virology')
df['Journal title'] = df['Journal title'].str.replace('Immunol ', 'Immunology')
df['Journal title'] = df['Journal title'].str.replace('Mol ', 'Molecular ') 

            
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
# 4   23438216 PMC3601604        ACS        Journal Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
df['Journal title'] = df['Journal title'].str.replace('Infect ', 'Infection ')
df['Journal title'] = df['Journal title'].str.replace('Biosci', 'Bioscience')
df['Journal title'] = df['Journal title'].str.replace('Org ', 'Organic ')
df['Journal title'] = df['Journal title'].str.replace('(', '') #taking out punctuation
df['Journal title'] = df['Journal title'].str.replace(')', '')
df['Journal title'] = df['Journal title'].str.replace('.', '')
df['Journal title'] = df['Journal title'].str.replace(',', '')

df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
# 4   23438216 PMC3601604        ACS    Journal Organic Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# Now to avoid all capitalization problems

df['Journal'] = df['Journal title'].str.upper() 

# I should've done this in the beginning before I made my replacements
# but the code was already typed out, and I've already made enough tedious changes.

df.head(4)
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
#
#   COST (£) charged to Wellcome (inc VAT when charged)                 Journal
# 0                                              £0.00   PSYCHOLOGICAL MEDICINE
# 1                                           £2381.04        BIOMACROMOLECULES
# 2                                            £642.56     JOURNAL MEDICAL CHEM
# 3                                            £669.64     JOURNAL MEDICAL CHEM

# %%
df2 = df
df2['Publisher'].replace('CUP', 'dog', inplace=True)
df2['Publisher'] = df2['Publisher'].replace('dog', 'ACS')
df2.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       ACS  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)                 Journal
# 0                                              £0.00   PSYCHOLOGICAL MEDICINE
# 1                                           £2381.04        BIOMACROMOLECULES
# 2                                            £642.56               J MED CHEM
# 3                                            £669.64               J MED CHEM
# 4                                            £685.88               J ORG CHEM

# %%
df.Journal.value_counts()
# Out:
# PLOS ONE                                                           190
# JOURNAL OF BIOLOGICAL CHEMISTRY                                     60
# NEUROIMAGE                                                          29
# PLOS PATHOGENS                                                      24
# PLOS GENETICS                                                       24
# NUCLEIC ACIDS RESEARCH                                              23
# PLOS NEGLECTED TROPICAL DISEASES                                    20
# PROCEEDINGS OF NATIONAL ACADEMY OF SCIENCES                         20
# NATURE COMMUNICATIONS                                               19
# HUMAN MOLECULAR GENETICS                                            19
# BIOCHEMICAL JOURNAL                                                 14
# BMC PUBLIC HEALTH                                                   14
# BRAIN                                                               14
# JOURNAL OF NEUROSCIENCE                                             14
# MOVEMENT DISORDERS                                                  13
# BMJ                                                                 12
# DEVELOPMENTAL CELL                                                  12
# JOURNAL OF GENERAL VIROLOGY                                         11
# CURRENT BIOLOGY                                                     11
# FASEB JOURNAL                                                       11
# CELL REPORTS                                                         9
# JOURNAL OF PHYSIOLOGY                                                9
# PLOSONE                                                              9
# NEURON                                                               9
# PLOS COMPUTATIONAL BIOLOGY                                           9
# BMJOURNAL OPEN                                                       9
# EMBO JOURNAL                                                         9
# MALARIA JOURNAL                                                      8
# JOURNAL OF VIROLOGY                                                  8
# JOURNAL OF CELL SCIENCE                                              8
#                                                                   ...
# NATURE NEUROSCIENCE                                                  1
# PFLUGERS ARCHIV                                                      1
# OSTEOARTHRITIS AND CARTILAGE                                         1
# MAGNETIC RESONANCE IN MEDICINE                                       1
# MOLECULAR GENETICS AND GENOMIC MEDICINE                              1
# BIOCONJUGATE CHEMISTRY                                               1
# PROCEEDINGS OF NATIONAL ACADEMY OF SCIENCES PNAS                     1
# PROTEIN ENGINEERING DESIGN AND SELECTION                             1
# BRITSH JOURNAL OF PSYCHIATRY                                         1
# VIROLOGY JOURNAL                                                     1
# FREE RADICAL AND BIOLOGY MEDICINE                                    1
# TRENDS IN COGNITIVE SCIENCE                                          1
# LANCET GLOBAL HEALTH                                                 1
# JOURNAL OF AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY       1
# JOURNAL OF MEDICINAL CHEMISTRY                                       1
# BMC MOLECULAR BIOLOGY                                                1
# DEVELOPMENT DYNAMICS                                                 1
# ACTA CRYSTALLOGRAPHICA SECTION D  BIOLOGICAL CRYSTALLOGRAPHY         1
# CLINICAL RADIOLOGY                                                   1
# CURRENT OPINION IN NEUROBIOLOGY                                      1
# MOLECULAR PHYLOGENETICS AND EVOLUTION                                1
# CLINICAL NEUROLOGY AND NEUROSURGERY                                  1
# DEPRESSION AND ANXIETY                                               1
# EUROPEAN JOURNAL OF PREVENTIVE CARDIOLOGY                            1
# FRONTIERS IN DECISION NEUROSCIENCE                                   1
# STATISTICS IN MEDICINE                                               1
# COGNITION                                                            1
# FRONTIERS IN COGNITIVE SCIENCE                                       1
# AMERICAN JOURNAL OF PSYCHIATRY                                       1
# TRANSACTIONS OF ROYAL SOCIETY OF TROPICAL MEDICINE AND HYGIENE       1
# Name: Journal, Length: 889, dtype: int64

# %% [markdown]
# ## Answer to Question 1: The top five most common Journals are:
# 1. PLoS One (190 articles)
# 2. Journal of Biological Chemistry (60 articles)
# 3. Neuroimage (29 articles)
# 4. PLoS Pathogens (24 articles)
# 5. PLoS Genetics (24 articles)

# %%
# there can still be more cleaning to do, but I think it's good for now...


# for second goal: Next, calculate the mean, median, and stan. dev of the cost per article for EACH JOURNAL.
df.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)':'Cost'},inplace=True)

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
# 4   23438216 PMC3601604        ACS    Journal Organic Chem
#
#                                        Article title      Cost  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88
#
#                   Journal
# 0  PSYCHOLOGICAL MEDICINE
# 1       BIOMACROMOLECULES
# 2    JOURNAL MEDICAL CHEM
# 3    JOURNAL MEDICAL CHEM
# 4    JOURNAL ORGANIC CHEM

# %%
dfFixedCost = []
for value in df.Cost:
    newvalue = value.replace("£", "") # The split method proposed by Thinkful works too!
    dfFixedCost.append(newvalue)
    
df['FixedCost'] = dfFixedCost
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
# 4   23438216 PMC3601604        ACS    Journal Organic Chem
#
#                                        Article title      Cost  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88
#
#                   Journal FixedCost
# 0  PSYCHOLOGICAL MEDICINE      0.00
# 1       BIOMACROMOLECULES   2381.04
# 2    JOURNAL MEDICAL CHEM    642.56
# 3    JOURNAL MEDICAL CHEM    669.64
# 4    JOURNAL ORGANIC CHEM    685.88

# %%
len(df)
# Out:
# 2127

# %%
dfFixedCost[485:495]
# Out:
# ['2539.89',
#  '2515.57',
#  '1366.08',
#  '3208.69',
#  '3948.42',
#  '4163.88',
#  '999999.00',
#  '2363.14',
#  '3838.88',
#  '4041.05']

# %%
# So the above cell shows two things:
# (1) There are broken values that need fixing
# (2) The quotes show that these numbers are strings, confirmed below...
print(dfFixedCost[1])
print(dfFixedCost[2])
print(dfFixedCost[1] + dfFixedCost[2])
type(dfFixedCost[1])
# Out:
# 2381.04
# 642.56
# 2381.04642.56
# str

# %%
dfFixedCost = df['FixedCost'] # I screwed up the list with a lambda function - had to reset the values
print(type(dfFixedCost[1])) # just to triple check the object type

dfFixedCosttemp = [] # I tried all other simpler ways of converting to float...

for value in dfFixedCost:
    value = ''.join(value.split('$'))
    value = float(value)
    dfFixedCosttemp.append(value)  # required to overwrite and map accordingly

dfFixedCost = dfFixedCosttemp
dfFixedCost[1] + dfFixedCost[2]
# Out:
# <class 'str'>
# 3023.6

# %%
# okay, now that all string values are FINALLY converted to float...
# time to fix erroneous outlier values
dfFixedCostnorm = [x for x in dfFixedCost if x < 10000]
print(np.median(dfFixedCostnorm))
print(np.mean(dfFixedCostnorm))
# Out:
# 1851.29
# 1822.0559075589792

# %%
# going to use median...
# list comprehension syntax
# [x for x in LIST if x CONDITION]
# OR USE: [x if CONDITION else CONDITION2 for x in LIST]


dfFixedCost = [x if x < 10000 else 1851.29 for x in dfFixedCost] # again, the median for a list of all non-outlier values
dfFixedCost[485:495]
# Out:
# [2539.89,
#  2515.57,
#  1366.08,
#  3208.69,
#  3948.42,
#  4163.88,
#  1851.29,
#  2363.14,
#  3838.88,
#  4041.05]

# %%
# plugging back into df
df['FixedCost'] = dfFixedCost
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS    Journal Medical Chem
# 3    23438330 PMC3646402       ACS    Journal Medical Chem
# 4   23438216 PMC3601604        ACS    Journal Organic Chem
#
#                                        Article title      Cost  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88
#
#                   Journal  FixedCost
# 0  PSYCHOLOGICAL MEDICINE       0.00
# 1       BIOMACROMOLECULES    2381.04
# 2    JOURNAL MEDICAL CHEM     642.56
# 3    JOURNAL MEDICAL CHEM     669.64
# 4    JOURNAL ORGANIC CHEM     685.88

# %%
print("The mean of the open-access cost per article is ${} +/- ${}.".format(np.mean(df.FixedCost), np.std(df.FixedCost)))
print("The median cost of the open-access cost per article is ${}.".format(np.median(df.FixedCost)))
# Out:
# The mean of the open-access cost per article is $1822.743121767748 +/- $758.4519244115404.
# The median cost of the open-access cost per article is $1851.29.

# %%
# determining central tendencies for * each journal *, as requested by question 2:

# now for the groupby grand finale!!!!
dftest = df # made this new df as to avoid screwing up original df
dftest1 = df.groupby(by='Journal').FixedCost.std().reset_index()
dftest1.columns = ('Journal', 'Stan. Dev.') # had to rename the std numerical column
dftest2 = df.groupby(by='Journal').FixedCost.mean().reset_index()
dftest2.columns = ('Journal', 'Average Cost')
dftest3 = df.groupby(by='Journal').FixedCost.median().reset_index()
dftest3.columns = ('Journal', 'Median Cost')

# pd.concat didn't work - it overwrote the numerical columns - did a manual pd.merge
dftestfinal = pd.merge(dftest3, dftest2)
dftestfinal = pd.merge(dftestfinal, dftest1)
dftestfinal = dftestfinal.sort_values(by=['Median Cost'], ascending=False)
dftestfinal.head()
# Out:
#                    Journal  Median Cost  Average Cost   Stan. Dev.
# 798  PUBLIC SERVICE REVIEW     6000.000     6000.0000          NaN
# 618       LANCET NEUROLOGY     5040.000     5040.0000  1018.233765
# 614                 LANCET     4677.005     4618.5025   230.322752
# 242              CURR BIOL     4151.770     4151.7700          NaN
# 193           CELL JOURNAL     4041.050     4041.0500          NaN

# %%
# fixing NaN's
dftestfinal['Stan. Dev.'].fillna(0, inplace=True)
#  had to do this^^^ instead of list comprehension because 'NaN' is not a string, and not a number (obviously)

# ANSWER TO QUESTION 2:
dftestfinal.head()
# Out:
#                    Journal  Median Cost  Average Cost   Stan. Dev.
# 798  PUBLIC SERVICE REVIEW     6000.000     6000.0000     0.000000
# 618       LANCET NEUROLOGY     5040.000     5040.0000  1018.233765
# 614                 LANCET     4677.005     4618.5025   230.322752
# 242              CURR BIOL     4151.770     4151.7700     0.000000
# 193           CELL JOURNAL     4041.050     4041.0500     0.000000

# %% [markdown]
# ### For third goal: identify the open access prices paid by subject area.
#
# For open-access prices, groupby identify the open access prices paid by subject area.
# HOW DO I DO THIS? What is meant by "subject area?" there is no column with such information.

# %%
dftestfinal.head()
# Out:
#                    Journal  Median Cost  Average Cost   Stan. Dev.
# 812  PUBLIC SERVICE REVIEW      6000.00   6000.000000     0.000000
# 891   THE LANCET NEUROLOGY      5040.00   5040.000000  1018.233765
# 627                 LANCET      4800.00   4800.000000     0.000000
# 890             THE LANCET      4554.01   4558.003333   240.024915
# 196    CELL HOST & MICROBE      4226.04   4226.040000     0.000000

# %%
# creating keyword lists

genrebio = set(['BIOLOGY', 'BIOLOGICAL', 'BIOL', 'CELL'])
genrechem = set(['CHEMISTRY', 'CHEMICAL', 'BIOCHEMISTRY', 'BIOCHEM'])
genremicro = set(['MICROBIOLOGY', 'VIRULOLOGY', 'MICROBIOL', 'IMMUNOLOGY'])
genrephysics = set(['PHYSICS', 'PHYSICAL'])
genregenetics = set(['GENETICS', 'GENETIC'])
genreneurology = set(['NEUROLOGY', 'NEURO', 'NEUROSCIENCE'])

# %%
dfgenre = dftestfinal # making new df in case I screw up the data

# %%
dfgenre['Subject Area'] = dfgenre.Journal
dfgenre.head(7)
# Out:
#                    Journal  Median Cost  Average Cost   Stan. Dev.  \
# 798  PUBLIC SERVICE REVIEW     6000.000     6000.0000     0.000000
# 618       LANCET NEUROLOGY     5040.000     5040.0000  1018.233765
# 614                 LANCET     4677.005     4618.5025   230.322752
# 242              CURR BIOL     4151.770     4151.7700     0.000000
# 193           CELL JOURNAL     4041.050     4041.0500     0.000000
# 192  CELL HOST AND MICROBE     4032.460     4032.4600   273.763461
# 417               IMMUNITY     3934.750     3934.7500   190.791552
#
#               Subject Area
# 798  PUBLIC SERVICE REVIEW
# 618       LANCET NEUROLOGY
# 614                 LANCET
# 242              CURR BIOL
# 193           CELL JOURNAL
# 192  CELL HOST AND MICROBE
# 417               IMMUNITY

# %%
# Careful of running this cell! 
# It's very process-heavy!!!!! Use judiciously!

for i in range(dfgenre.shape[0]):
    tokens = set(dfgenre.Journal.iloc[i].split())
    if len(tokens.intersection(genreneurology)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Neurology'
        
    elif len(tokens.intersection(genrebio)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Biology'
        
    elif len(tokens.intersection(genrechem)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Chemistry'    
    
    elif len(tokens.intersection(genremicro)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Microbiology'
    
    elif len(tokens.intersection(genrephysics)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Physics'
    
    elif len(tokens.intersection(genregenetics)) > 0:
        dfgenre['Subject Area'].iloc[i] = 'Genetics'
        
    else:
        dfgenre['Subject Area'].iloc[i] = 'Other' 
        # ^^^^This is why I put it in a single loop instead of breaking it up:
        # I don't want to overwrite everything with "Other", 
        # which would happen if I broke it up into multiple loops

# %%
dfgenre.head()
# Out:
#                    Journal  Median Cost  Average Cost   Stan. Dev.  \
# 798  PUBLIC SERVICE REVIEW     6000.000     6000.0000     0.000000
# 618       LANCET NEUROLOGY     5040.000     5040.0000  1018.233765
# 614                 LANCET     4677.005     4618.5025   230.322752
# 242              CURR BIOL     4151.770     4151.7700     0.000000
# 193           CELL JOURNAL     4041.050     4041.0500     0.000000
#
#     Subject Area
# 798        Other
# 618    Neurology
# 614        Other
# 242      Biology
# 193      Biology

# %%
# Answer to question 3:
dfgenre
# Out:
#                                                Journal  Median Cost  \
# 798                              PUBLIC SERVICE REVIEW     6000.000
# 618                                   LANCET NEUROLOGY     5040.000
# 614                                             LANCET     4677.005
# 242                                          CURR BIOL     4151.770
# 193                                       CELL JOURNAL     4041.050
# 192                              CELL HOST AND MICROBE     4032.460
# 417                                           IMMUNITY     3934.750
# 695                                             NEURON     3918.420
# 194                                    CELL METABOLISM     3904.460
# 847                                          STRUCTURE     3895.640
# 195                          CELL PRESS - CELL REPORTS     3884.400
# 265                                 DEVELOPMENTAL CELL     3861.420
# 245                                    CURRENT BIOLOGY     3857.160
# 196                                       CELL REPORTS     3836.320
# 69              ANTIMICROBIAL AGFENTS AND CHEMOTHERAPY     3750.050
# 656                                     MOLECULAR CELL     3722.390
# 616                               LANCET GLOBAL HEALTH     3678.780
# 673                              NATURE COMMUNICATIONS     3642.000
# 260                                   DEVELOPMENT CELL     3630.640
# 471                  JOURNAL OD CLINICAL ENDOCRINOLOGY     3602.410
# 676                         NEGLECTED TROPICAL DISEASE     3600.000
# 617                               LANCET INFECTION DIS     3600.000
# 197                                     CELL STEM CELL     3534.065
# 717                                           ONCOGENE     3360.000
# 621                                           LEUKEMIA     3240.000
# 82                             BEHAVIORAL NEUROSCIENCE     3209.630
# 183                                               CELL     3208.690
# 395                                  HEALTH PSYCHOLOGY     3188.300
# 205                              CEREBRAL CORTEX PRINT     3177.600
# 531  JOURNAL OF EXPERIMENTAL PSYCHOLOGY:  ANIMAL BE...     3144.240
# ..                                                 ...          ...
# 664                                    MOLECULAR PHARM      649.330
# 451              INTERNATIONAL JOURNAL OF RHEUMATOLOGY      626.000
# 358                         FRONTIERS IN NEUROROBOTICS      625.200
# 584                   JOURNAL OF PARASITOLOGY RESEARCH      623.950
# 772  PROCEDDINGS OF NATIONAL ACADEMY OF SCIENCES OF...      619.830
# 555                        JOURNAL OF MEDICAL VIROLOGY      612.590
# 78                                           AUTOPHAGY      601.100
# 538                    JOURNAL OF HISTORICAL GEOGRAPHY      596.460
# 776  PROCEEDINGS OF NATIONAL ACADEMY OF SCIENCES OF...      584.675
# 391                                           HEALTH        551.270
# 853                                       THERANOSTICS      543.290
# 606                 JOURNAL OF VISUALIZED EXPERIEMENTS      517.500
# 289                                         EPIGENTICS      508.660
# 812                                        RNA BIOLOGY      494.960
# 288                                        EPIGENETICS      490.485
# 707                                     NEUROSCIENTIST      480.930
# 343                     FRONTIERS IN COGNITIVE SCIENCE      434.700
# 467                              JOURNAL INFECTION DIS      378.780
# 389                  HAEMATOLOGICA/HAEMATOLOGY JOURNAL      378.700
# 349                              FRONTIERS IN GENETICS      346.250
# 745                  PHYSICS IN BIOLOGY AND MEDICINE\n      340.000
# 184                        CELL ADHESION AND MIGRATION      321.460
# 558                    JOURNAL OF MEDICINAL CHEMISTRY       321.120
# 292                             ESSAYS IN BIOCHEMISTRY      270.000
# 444      INTERNATIONAL JOURNAL OF FINANCIAL RESEARCH\n      187.030
# 573  JOURNAL OF NEUROLOGY AND TRANSLATIONAL NEUROSC...      159.910
# 206                                           CHANNELS      159.740
# 502       JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING      135.290
# 53                      AMERICAN SOCIETY FOR NUTRITION       45.940
# 882                                VETERINARY RESEARCH        9.930
#
#      Average Cost   Stan. Dev. Subject Area
# 798   6000.000000     0.000000        Other
# 618   5040.000000  1018.233765    Neurology
# 614   4618.502500   230.322752        Other
# 242   4151.770000     0.000000      Biology
# 193   4041.050000     0.000000      Biology
# 192   4032.460000   273.763461      Biology
# 417   3934.750000   190.791552        Other
# 695   3565.644444  1116.765911        Other
# 194   3924.260000   151.324659      Biology
# 847   3881.824286   166.835165        Other
# 195   3884.400000     0.000000      Biology
# 265   3292.271667  1253.021067      Biology
# 245   3511.682727  1077.043187      Biology
# 196   3644.226667   369.735186      Biology
# 69    3750.050000     0.000000        Other
# 656   3095.958000  1146.221171      Biology
# 616   3678.780000     0.000000        Other
# 673   3066.615263   894.273870        Other
# 260   3630.640000     0.000000      Biology
# 471   3602.410000     0.000000        Other
# 676   3600.000000     0.000000        Other
# 617   3600.000000     0.000000        Other
# 197   3534.065000   257.422224      Biology
# 717   3164.816667   338.067450        Other
# 621   3240.000000   339.411255        Other
# 82    3147.706667   109.112900    Neurology
# 183   2907.672000  1249.427429      Biology
# 395   3188.300000     0.000000        Other
# 205   3177.600000     0.000000        Other
# 531   3144.240000     0.000000        Other
# ..            ...          ...          ...
# 664    649.330000     0.000000        Other
# 451    626.000000     0.000000        Other
# 358    625.200000     0.000000        Other
# 584    623.950000     0.000000        Other
# 772    619.830000     0.000000        Other
# 555    612.590000     0.000000        Other
# 78     601.100000     0.000000        Other
# 538    596.460000     0.000000        Other
# 776    584.675000    24.076986        Other
# 391    551.270000     0.000000        Other
# 853    543.290000     0.000000        Other
# 606    517.500000     0.000000        Other
# 289    508.660000   139.837437        Other
# 812    490.123333    85.387799      Biology
# 288    490.485000     3.655742        Other
# 707    480.930000     0.000000        Other
# 343    434.700000     0.000000        Other
# 467    378.780000     0.000000        Other
# 389    378.700000     0.000000        Other
# 349    346.250000     0.000000     Genetics
# 745    340.000000     0.000000      Biology
# 184    321.460000     0.000000      Biology
# 558    321.120000     0.000000    Chemistry
# 292    270.000000     0.000000    Chemistry
# 444    187.030000     0.000000        Other
# 573    159.910000     0.000000    Neurology
# 206    159.740000     0.000000        Other
# 502    135.290000     0.000000        Other
# 53      45.940000     0.000000        Other
# 882      9.930000     0.000000        Other
#
# [889 rows x 5 columns]
